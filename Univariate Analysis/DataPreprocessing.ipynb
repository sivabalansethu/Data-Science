# %%
import pandas as pd
import numpy as np

# %%
original_dataset=pd.read_csv("Placement.csv")

# %%
original_dataset.isnull().sum()
# or original_dataset.isna().sum()
# Yes, it has null values
# Out:
# sl_no              0
# gender             0
# ssc_p              0
# ssc_b              0
# hsc_p              0
# hsc_b              0
# hsc_s              0
# degree_p           0
# degree_t           0
# workex             0
# etest_p            0
# specialisation     0
# mba_p              0
# status             0
# salary            67
# dtype: int64

# %%
original_dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
original_dataset=original_dataset.fillna(0)
#Missing values can be replaced with SimpleImputer Refer - https://vitalflux.com/imputing-missing-data-sklearn-simpleimputer/

# %%
original_dataset.isnull().sum()
# Since Candidate is not placed, Salary should be 0.
# Out:
# sl_no             0
# gender            0
# ssc_p             0
# ssc_b             0
# hsc_p             0
# hsc_b             0
# hsc_s             0
# degree_p          0
# degree_t          0
# workex            0
# etest_p           0
# specialisation    0
# mba_p             0
# status            0
# salary            0
# dtype: int64

# %% [markdown]
# # Segregate Quantitative and Qualitative data

# %%
original_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 15 columns):
# sl_no             215 non-null int64
# gender            215 non-null object
# ssc_p             215 non-null float64
# ssc_b             215 non-null object
# hsc_p             215 non-null float64
# hsc_b             215 non-null object
# hsc_s             215 non-null object
# degree_p          215 non-null float64
# degree_t          215 non-null object
# workex            215 non-null object
# etest_p           215 non-null float64
# specialisation    215 non-null object
# mba_p             215 non-null float64
# status            215 non-null object
# salary            215 non-null float64
# dtypes: float64(6), int64(1), object(8)
# memory usage: 25.3+ KB

# %%
dir(original_dataset)
# Out:
# ['T',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_priority__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
# ...

# %%
original_dataset["gender"].dtypes
# Out:
# dtype('O')

# %%
quan=[]
qual=[]
for columnName in original_dataset.columns:
    #print(columnName)
    if(original_dataset[columnName].dtype=='O'):
        #print("qual")
        qual.append(columnName)
    else:
        #print("quan")
        quan.append(columnName)

# %% [markdown]
# # Univariate Analysis

# %%
univariate_analysis=pd.DataFrame(index=["Mean","Median","Mode","Q1:25%","Q2:50%",
                               "Q3:75%","99%","Q4:100%","IQR","1.5rule","Lesser","Greater",
                                    "Min","Max","kurtosis","skew","Var","Std"],columns=quan)

lesserOutlier=[]
greaterOutlier=[]

for columnName in quan:
    univariate_analysis[columnName]["Mean"]=original_dataset[columnName].mean()
    univariate_analysis[columnName]["Median"]=original_dataset[columnName].median()
    univariate_analysis[columnName]["Mode"]=original_dataset[columnName].mode()[0]
    univariate_analysis[columnName]["Q1:25%"]=np.percentile(original_dataset[columnName], 25)
    univariate_analysis[columnName]["Q2:50%"]=np.percentile(original_dataset[columnName], 50)
    univariate_analysis[columnName]["Q3:75%"]=np.percentile(original_dataset[columnName], 75)
    univariate_analysis[columnName]["99%"]=np.percentile(original_dataset[columnName], 99)
    univariate_analysis[columnName]["Q4:100%"]=np.percentile(original_dataset[columnName], 100)
    univariate_analysis[columnName]["IQR"]=univariate_analysis[columnName]["Q3:75%"]-univariate_analysis[columnName]["Q1:25%"]
    univariate_analysis[columnName]["1.5rule"]=1.5*univariate_analysis[columnName]["IQR"]
    univariate_analysis[columnName]["Lesser"]=univariate_analysis[columnName]["Q1:25%"]-univariate_analysis[columnName]["1.5rule"]
    univariate_analysis[columnName]["Greater"]=univariate_analysis[columnName]["Q3:75%"]+univariate_analysis[columnName]["1.5rule"]
    univariate_analysis[columnName]["Min"]=original_dataset[columnName].min()
    univariate_analysis[columnName]["Max"]=original_dataset[columnName].max()
    univariate_analysis[columnName]["kurtosis"]=original_dataset[columnName].kurtosis()
    univariate_analysis[columnName]["skew"]=original_dataset[columnName].skew()
    univariate_analysis[columnName]["Var"]=original_dataset[columnName].var()
    univariate_analysis[columnName]["Std"]=original_dataset[columnName].std()
    
    #Find out Outlier Variable
    if(univariate_analysis[columnName]["Min"] < univariate_analysis[columnName]["Lesser"]):
        lesserOutlier.append(columnName)
    if(univariate_analysis[columnName]["Max"] > univariate_analysis[columnName]["Greater"]):
        greaterOutlier.append(columnName)

print(lesserOutlier)
print(greaterOutlier)
# Out:
# ['hsc_p']
# ['hsc_p', 'degree_p', 'salary']

# %%
#Replace outlier in Lesser and Greater
for columnName in lesserOutlier:
    original_dataset[columnName][original_dataset[columnName] < univariate_analysis[columnName]["Lesser"]]=univariate_analysis[columnName]["Lesser"]

for columnName in greaterOutlier:
    original_dataset[columnName][original_dataset[columnName] > univariate_analysis[columnName]["Greater"]]=univariate_analysis[columnName]["Greater"]
# Out:
# C:\Users\Hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#univariate_analysis["ssc_p"]["Q1:25%"]=np.percentile(original_dataset["ssc_p"],99)

# %%
univariate_analysis_no_outlier=pd.DataFrame(index=["Mean","Median","Mode","Q1:25%","Q2:50%",
                               "Q3:75%","99%","Q4:100%","IQR","1.5rule","Lesser","Greater",
                                    "Min","Max","kurtosis","skew","Var","Std"],columns=quan)

lesserOutlier=[]
greaterOutlier=[]

for columnName in quan:
    univariate_analysis_no_outlier[columnName]["Mean"]=original_dataset[columnName].mean()
    univariate_analysis_no_outlier[columnName]["Median"]=original_dataset[columnName].median()
    univariate_analysis_no_outlier[columnName]["Mode"]=original_dataset[columnName].mode()[0]
    univariate_analysis_no_outlier[columnName]["Q1:25%"]=np.percentile(original_dataset[columnName], 25)
    univariate_analysis_no_outlier[columnName]["Q2:50%"]=np.percentile(original_dataset[columnName], 50)
    univariate_analysis_no_outlier[columnName]["Q3:75%"]=np.percentile(original_dataset[columnName], 75)
    univariate_analysis_no_outlier[columnName]["99%"]=np.percentile(original_dataset[columnName], 99)
    univariate_analysis_no_outlier[columnName]["Q4:100%"]=np.percentile(original_dataset[columnName], 100)
    univariate_analysis_no_outlier[columnName]["IQR"]=univariate_analysis[columnName]["Q3:75%"]-univariate_analysis[columnName]["Q1:25%"]
    univariate_analysis_no_outlier[columnName]["1.5rule"]=1.5*univariate_analysis[columnName]["IQR"]
    univariate_analysis_no_outlier[columnName]["Lesser"]=univariate_analysis[columnName]["Q1:25%"]-univariate_analysis[columnName]["1.5rule"]
    univariate_analysis_no_outlier[columnName]["Greater"]=univariate_analysis[columnName]["Q3:75%"]+univariate_analysis[columnName]["1.5rule"]
    univariate_analysis_no_outlier[columnName]["Min"]=original_dataset[columnName].min()
    univariate_analysis_no_outlier[columnName]["Max"]=original_dataset[columnName].max()
    univariate_analysis_no_outlier[columnName]["kurtosis"]=original_dataset[columnName].kurtosis()
    univariate_analysis_no_outlier[columnName]["skew"]=original_dataset[columnName].skew()
    univariate_analysis_no_outlier[columnName]["Var"]=original_dataset[columnName].var()
    univariate_analysis_no_outlier[columnName]["Std"]=original_dataset[columnName].std()
    
    #Find out Outlier Variable
    if(univariate_analysis_no_outlier[columnName]["Min"] < univariate_analysis_no_outlier[columnName]["Lesser"]):
        lesserOutlier.append(columnName)
    if(univariate_analysis_no_outlier[columnName]["Max"] > univariate_analysis_no_outlier[columnName]["Greater"]):
        greaterOutlier.append(columnName)

print(lesserOutlier)
print(greaterOutlier)
# Out:
# []
# []

# %%
univariate_analysis_no_outlier
# Out:
#             sl_no     ssc_p      hsc_p   degree_p   etest_p     mba_p  \
# Mean          108   67.3034    66.3347    66.3586   72.1006   62.2782
# Median        108        67         65         66        71        62
# Mode            1        62         63         65        60      56.7
# Q1:25%       54.5      60.6       60.9         61        60    57.945
# Q2:50%        108        67         65         66        71        62
# Q3:75%      161.5      75.7         73         72      83.5    66.255
# 99%        212.86        87     91.129      83.86        97   76.1142
# Q4:100%       215      89.4      91.15       88.5        98     77.89
# IQR           107      15.1       12.1         11      23.5      8.31
# 1.5rule     160.5     22.65      18.15       16.5     35.25    12.465
# Lesser       -106     37.95      42.75       44.5     24.75     45.48
# Greater       322     98.35      91.15       88.5    118.75     78.72
# ...

# %%
#Find Outlier
#if(original_dataset["sl_no"]["Lesser"] > original_dataset["sl_no"]["Min"]):
#    print("Greater Than -- Outlier")

# %%
#Find Unique Value, Frequency, Relative Frequency, Cumulative Frequency
univariate_frequency_tbl=pd.DataFrame(columns=["Unique_Values","Frequency","Relative Frequency","Cumsum"])
univariate_frequency_tbl["Unique_Values"]=univariate_analysis_no_outlier["ssc_p"].value_counts().index
univariate_frequency_tbl["Frequency"]=univariate_analysis_no_outlier["ssc_p"].value_counts().values
univariate_frequency_tbl["Relative Frequency"]=univariate_frequency_tbl["Frequency"]/100
univariate_frequency_tbl["Cumsum"]=univariate_frequency_tbl["Relative Frequency"].cumsum()

# %%
univariate_frequency_tbl
# Out:
#     Unique_Values  Frequency  Relative Frequency  Cumsum
# 0       89.400000          2                0.02    0.02
# 1       67.000000          2                0.02    0.04
# 2       62.000000          1                0.01    0.05
# 3       60.600000          1                0.01    0.06
# 4       87.000000          1                0.01    0.07
# 5       22.650000          1                0.01    0.08
# 6      117.228377          1                0.01    0.09
# 7       67.303395          1                0.01    0.10
# 8       15.100000          1                0.01    0.11
# 9       75.700000          1                0.01    0.12
# 10      10.827205          1                0.01    0.13
# 11      -0.132649          1                0.01    0.14
# 12      40.890000          1                0.01    0.15
# 13      37.950000          1                0.01    0.16
# 14      98.350000          1                0.01    0.17
# ...

# %%
original_dataset[qual].isnull().sum()
# Out:
# gender            0
# ssc_b             0
# hsc_b             0
# hsc_s             0
# degree_t          0
# workex            0
# specialisation    0
# status            0
# dtype: int64

# %%
# Replace null values with Mean - This is for sample one. In this Data, we should not use (Not Placed)... 
#import numpy as np
#from sklearn.impute import SimpleImputer
#imp = SimpleImputer(missing_values=np.nan, strategy='mean')
#imp.fit(original_dataset[quan])
#df=imp.transform(original_dataset[quan])
#df = pd.DataFrame(df,columns = quan)

# %%
# Out:
#      sl_no  ssc_p  hsc_p  degree_p  etest_p  mba_p    salary
# 0        1  67.00  91.00     58.00     55.0  58.80  270000.0
# 1        2  79.33  78.33     77.48     86.5  66.28  200000.0
# 2        3  65.00  68.00     64.00     75.0  57.80  250000.0
# 3        4  56.00  52.00     52.00     66.0  59.43       0.0
# 4        5  85.80  73.60     73.30     96.8  55.50  425000.0
# ..     ...    ...    ...       ...      ...    ...       ...
# 210    211  80.60  82.00     77.60     91.0  74.49  400000.0
# 211    212  58.00  60.00     72.00     74.0  53.62  275000.0
# 212    213  67.00  67.00     73.00     59.0  69.72  295000.0
# 213    214  74.00  66.00     58.00     70.0  60.23  204000.0
# 214    215  62.00  58.00     53.00     89.0  60.22       0.0
#
# [215 rows x 7 columns]

# %%
categoricalData=original_dataset[qual]

# %%
quantitativeData=original_dataset[quan]

# %%
quantitativeData
# Out:
#      sl_no  ssc_p  hsc_p  degree_p  etest_p  mba_p    salary
# 0        1  67.00  91.00     58.00     55.0  58.80  270000.0
# 1        2  79.33  78.33     77.48     86.5  66.28  200000.0
# 2        3  65.00  68.00     64.00     75.0  57.80  250000.0
# 3        4  56.00  52.00     52.00     66.0  59.43       0.0
# 4        5  85.80  73.60     73.30     96.8  55.50  425000.0
# ..     ...    ...    ...       ...      ...    ...       ...
# 210    211  80.60  82.00     77.60     91.0  74.49  400000.0
# 211    212  58.00  60.00     72.00     74.0  53.62  275000.0
# 212    213  67.00  67.00     73.00     59.0  69.72  295000.0
# 213    214  74.00  66.00     58.00     70.0  60.23  204000.0
# 214    215  62.00  58.00     53.00     89.0  60.22       0.0
#
# [215 rows x 7 columns]

# %%
categoricalData
# Out:
#     gender    ssc_b    hsc_b     hsc_s   degree_t workex specialisation  \
# 0        M   Others   Others  Commerce   Sci&Tech     No         Mkt&HR
# 1        M  Central   Others   Science   Sci&Tech    Yes        Mkt&Fin
# 2        M  Central  Central      Arts  Comm&Mgmt     No        Mkt&Fin
# 3        M  Central  Central   Science   Sci&Tech     No         Mkt&HR
# 4        M  Central  Central  Commerce  Comm&Mgmt     No        Mkt&Fin
# ..     ...      ...      ...       ...        ...    ...            ...
# 210      M   Others   Others  Commerce  Comm&Mgmt     No        Mkt&Fin
# 211      M   Others   Others   Science   Sci&Tech     No        Mkt&Fin
# 212      M   Others   Others  Commerce  Comm&Mgmt    Yes        Mkt&Fin
# 213      F   Others   Others  Commerce  Comm&Mgmt     No         Mkt&HR
# 214      M  Central   Others   Science  Comm&Mgmt     No         Mkt&HR
#
#          status
# 0        Placed
# 1        Placed
# 2        Placed
# 3    Not Placed
# ...

# %%
mergeList=[quantitativeData,categoricalData]

# %%
mergeList
# Out:
# [            sl_no     ssc_p      hsc_p   degree_p   etest_p     mba_p  \
#  Mean          108   67.3034    66.3347    66.3586   72.1006   62.2782
#  Median        108        67         65         66        71        62
#  Mode            1        62         63         65        60      56.7
#  Q1:25%       54.5      60.6       60.9         61        60    57.945
#  Q2:50%        108        67         65         66        71        62
#  Q3:75%      161.5      75.7         73         72      83.5    66.255
#  99%        212.86        87     91.129      83.86        97   76.1142
#  Q4:100%       215      89.4      91.15       88.5        98     77.89
#  IQR           107      15.1       12.1         11      23.5      8.31
#  1.5rule     160.5     22.65      18.15       16.5     35.25    12.465
#  Lesser       -106     37.95      42.75       44.5     24.75     45.48
#  Greater       322     98.35      91.15       88.5    118.75     78.72
# ...

# %%
preprocessedData=pd.concat(mergeList,axis=1)
# axis=1 -> Columnwise concat

# %%
preprocessedData
# Out:
#      sl_no  ssc_p  hsc_p  degree_p  etest_p  mba_p    salary gender    ssc_b  \
# 0        1  67.00  91.00     58.00     55.0  58.80  270000.0      M   Others
# 1        2  79.33  78.33     77.48     86.5  66.28  200000.0      M  Central
# 2        3  65.00  68.00     64.00     75.0  57.80  250000.0      M  Central
# 3        4  56.00  52.00     52.00     66.0  59.43       0.0      M  Central
# 4        5  85.80  73.60     73.30     96.8  55.50  425000.0      M  Central
# ..     ...    ...    ...       ...      ...    ...       ...    ...      ...
# 210    211  80.60  82.00     77.60     91.0  74.49  400000.0      M   Others
# 211    212  58.00  60.00     72.00     74.0  53.62  275000.0      M   Others
# 212    213  67.00  67.00     73.00     59.0  69.72  295000.0      M   Others
# 213    214  74.00  66.00     58.00     70.0  60.23  204000.0      F   Others
# 214    215  62.00  58.00     53.00     89.0  60.22       0.0      M  Central
#
# ...

# %%
preprocessedData.isnull().sum()
# Out:
# sl_no             0
# ssc_p             0
# hsc_p             0
# degree_p          0
# etest_p           0
# mba_p             0
# salary            0
# gender            0
# ssc_b             0
# hsc_b             0
# hsc_s             0
# degree_t          0
# workex            0
# specialisation    0
# status            0
# dtype: int64

# %%
preprocessedData.to_csv("preprocessed_placementdata.csv",index=False)
